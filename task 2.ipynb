# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px 
import seaborn as sns

# %%
df=pd.read_excel('MLCOE society task 2.xlsx')

# %%
df.head(10)
# Out:
#    Customer ID   Age Gender Item Purchased     Category  \
# 0            1   NaN   Male         Blouse     Clothing
# 1            2   NaN   Male        Sweater     Clothing
# 2            3   NaN   Male          Jeans     Clothing
# 3            4   NaN   Male        Sandals     Footwear
# 4            5   NaN   Male         Blouse     Clothing
# 5            6   NaN   Male       Sneakers     Footwear
# 6            7   NaN   Male          Shirt     Clothing
# 7            8   NaN   Male         Shorts     Clothing
# 8            9   NaN   Male           Coat    Outerwear
# 9           10  57.0   Male        Handbag  Accessories
#
#    Purchase Amount (USD)       Location Size      Color  Season  \
# 0                    NaN       Kentucky    L       Gray  Winter
# 1                    NaN          Maine    L     Maroon  Winter
# 2                    NaN  Massachusetts    S     Maroon  Spring
# 3                   90.0   Rhode Island    M     Maroon  Spring
# ...

# %%
df.tail()
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                   28.0    Virginia    L  Turquoise  Summer
# 3896                   49.0        Iowa    L      White  Spring
# 3897                   33.0  New Jersey    L      Green  Spring
# 3898                   77.0   Minnesota    S      Brown  Summer
# 3899                    NaN  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                ille         PayPal    Store Pickup
# ...

# %%
df.sort_values("Item Purchased" , ascending=False)
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 2799         2800  23.0  Female        T-shirt     Clothing
# 185           186   NaN    Male        T-shirt     Clothing
# 904           905  69.0    Male        T-shirt     Clothing
# 2474         2475  23.0    Male        T-shirt     Clothing
# 1948         1949  54.0    Male        T-shirt     Clothing
# ...           ...   ...     ...            ...          ...
# 1567         1568   NaN    Male       Backpack  Accessories
# 1564         1565  22.0    Male       Backpack  Accessories
# 1557         1558   NaN    Male       Backpack  Accessories
# 3502         3503   NaN  Female       Backpack  Accessories
# 1950         1951  43.0    Male       Backpack  Accessories
#
#       Purchase Amount (USD)        Location Size      Color  Season  \
# 2799                   89.0           Maine    L       Pink  Spring
# 185                     NaN       Wisconsin   XL     Silver  Summer
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Customer ID   Age  Gender Item Purchased     Category  \
# 0               1   NaN    Male         Blouse     Clothing
# 1               2   NaN    Male        Sweater     Clothing
# 2               3   NaN    Male          Jeans     Clothing
# 3               4   NaN    Male        Sandals     Footwear
# 4               5   NaN    Male         Blouse     Clothing
# ...           ...   ...     ...            ...          ...
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                       NaN       Kentucky    L       Gray  Winter
# 1                       NaN          Maine    L     Maroon  Winter
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                   0
# Age                         631
# Gender                        0
# Item Purchased                0
# Category                      0
# Purchase Amount (USD)       615
# Location                      0
# Size                          0
# Color                         0
# Season                        0
# Review Rating               654
# Subscription Status           0
# Payment Method                0
# Shipping Type                 0
# Discount Applied              0
# Promo Code Used               0
# Previous Purchases            0
# Preferred Payment Method      0
# Frequency of Purchases        0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Age', 'Purchase Amount (USD)', 'Review Rating']

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_Season=pd.read_excel('MLCOE society task 2.xlsx')
df_Season.head(10)
# Out:
#    Customer ID   Age Gender Item Purchased     Category  \
# 0            1   NaN   Male         Blouse     Clothing
# 1            2   NaN   Male        Sweater     Clothing
# 2            3   NaN   Male          Jeans     Clothing
# 3            4   NaN   Male        Sandals     Footwear
# 4            5   NaN   Male         Blouse     Clothing
# 5            6   NaN   Male       Sneakers     Footwear
# 6            7   NaN   Male          Shirt     Clothing
# 7            8   NaN   Male         Shorts     Clothing
# 8            9   NaN   Male           Coat    Outerwear
# 9           10  57.0   Male        Handbag  Accessories
#
#    Purchase Amount (USD)       Location Size      Color  Season  \
# 0                    NaN       Kentucky    L       Gray  Winter
# 1                    NaN          Maine    L     Maroon  Winter
# 2                    NaN  Massachusetts    S     Maroon  Spring
# 3                   90.0   Rhode Island    M     Maroon  Spring
# ...

# %%
pd.merge(df,df_Season,on='Payment Method',how='left')
# Out:
#          Customer ID_x  Age_x Gender_x Item Purchased_x   Category_x  \
# 0                    1    NaN     Male           Blouse     Clothing
# 1                    1    NaN     Male           Blouse     Clothing
# 2                    1    NaN     Male           Blouse     Clothing
# 3                    1    NaN     Male           Blouse     Clothing
# 4                    1    NaN     Male           Blouse     Clothing
# ...                ...    ...      ...              ...          ...
# 2537881           3900   52.0   Female          Handbag  Accessories
# 2537882           3900   52.0   Female          Handbag  Accessories
# 2537883           3900   52.0   Female          Handbag  Accessories
# 2537884           3900   52.0   Female          Handbag  Accessories
# 2537885           3900   52.0   Female          Handbag  Accessories
#
#          Purchase Amount (USD)_x  Location_x Size_x Color_x Season_x  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3269 non-null   float64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3285 non-null   float64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3246 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.shape
# Out:
# (3900, 19)

# %%
df.rename(index=str,columns={'Category':'CATEGORY',
							 'Gender':'GENDER' ,
							 'Age':'AGE',
							 'Size':'SIZE',
							 'Color':'COLOR'},inplace=True)

# %%
df.head()
# Out:
#    Customer ID  AGE GENDER Item Purchased  CATEGORY  Purchase Amount (USD)  \
# 0            1  NaN   Male         Blouse  Clothing                    NaN
# 1            2  NaN   Male        Sweater  Clothing                    NaN
# 2            3  NaN   Male          Jeans  Clothing                    NaN
# 3            4  NaN   Male        Sandals  Footwear                   90.0
# 4            5  NaN   Male         Blouse  Clothing                    NaN
#
#         Location SIZE      COLOR  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            NaN                 yep
# 1          Maine    L     Maroon  Winter            NaN                 Yes
# 2  Massachusetts    S     Maroon  Spring            NaN                 Yes
# 3   Rhode Island    M     Maroon  Spring            NaN                 Yes
# 4         Oregon    M  Turquoise  Spring            NaN                  Yo
#
# ...

# %% [markdown]
# DATA CLEANING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   AGE                       3269 non-null   float64
#  2   GENDER                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   CATEGORY                  3900 non-null   object
#  5   Purchase Amount (USD)     3285 non-null   float64
#  6   Location                  3900 non-null   object
#  7   SIZE                      3900 non-null   object
#  8   COLOR                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3246 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.isnull().sum().sort_values(ascending=False) #CHECK MISSING VALUES FOR EACH COLUMNS
# Out:
# Review Rating               654
# AGE                         631
# Purchase Amount (USD)       615
# Customer ID                   0
# Subscription Status           0
# Preferred Payment Method      0
# Previous Purchases            0
# Promo Code Used               0
# Discount Applied              0
# Shipping Type                 0
# Payment Method                0
# Season                        0
# COLOR                         0
# SIZE                          0
# Location                      0
# CATEGORY                      0
# Item Purchased                0
# GENDER                        0
# Frequency of Purchases        0
# dtype: int64

# %%
df[df.isnull().any(axis=1)].head() #checkout the rows missings values
# Out:
#    Customer ID  AGE GENDER Item Purchased  CATEGORY  Purchase Amount (USD)  \
# 0            1  NaN   Male         Blouse  Clothing                    NaN
# 1            2  NaN   Male        Sweater  Clothing                    NaN
# 2            3  NaN   Male          Jeans  Clothing                    NaN
# 3            4  NaN   Male        Sandals  Footwear                   90.0
# 4            5  NaN   Male         Blouse  Clothing                    NaN
#
#         Location SIZE      COLOR  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            NaN                 yep
# 1          Maine    L     Maroon  Winter            NaN                 Yes
# 2  Massachusetts    S     Maroon  Spring            NaN                 Yes
# 3   Rhode Island    M     Maroon  Spring            NaN                 Yes
# 4         Oregon    M  Turquoise  Spring            NaN                  Yo
#
# ...
